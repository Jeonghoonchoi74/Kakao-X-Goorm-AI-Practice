# %% [markdown]
# # 문제: 서울시 공원 정보 시각화 프로젝트
#
# 서울시의 공원 데이터를 담고 있는 seoul_parks.csv 파일의 일부 활용 예시입니다:
#
# 다음의 조건을 만족하는 프로그램을 작성하세요.
#
# 📌 1단계: Pandas로 데이터 불러오기
# seoul_parks.csv 파일을 Pandas를 사용하여 불러오세요.
#
# 📌 2단계: matplotlib 시각화
# matplotlib을 사용하여 구별 공원 수를 바 차트로 시각화하세요.
#
# 📌 3단계: seaborn 시각화
# seaborn의 boxplot을 이용하여 구별 공원 면적의 분포를 시각화하세요.
#
# 📌 4단계: plotly 시각화
# plotly로 공원 면적에 따른 인터랙티브한 산점도를 그리세요. (x축: 면적, y축: 구, 마커: 공원이름)
#
# 📌 5단계: folium 지도 시각화
# folium을 사용하여 모든 공원의 위치를 마커로 지도에 표시하세요.
#
# 마커를 클릭하면 공원이름과 면적이 팝업으로 보이게 하세요.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 시스템에 설치된 한글 폰트 설정 (Windows 기준)
plt.rc('font', family='Malgun Gothic')  # '맑은 고딕' 폰트 사용
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

data = pd.read_csv('seoul_parks.csv')
data
# Out:
#         이름       위도        경도       면적    구
# 0    보라매공원  37.4991  126.9208   425992  동작구
# 1      서울숲  37.5446  127.0371  1165700  성동구
# 2     남산공원  37.5509  126.9905  1191416   중구
# 3    월드컵공원  37.5683  126.8986  2690000  마포구
# 4   어린이대공원  37.5485  127.0746   530000  광진구
# 5   용산가족공원  37.5233  126.9802    75000  용산구
# 6  응봉산근린공원  37.5584  127.0343   200000  성동구
# 7  우장산근린공원  37.5410  126.8365   300000  강서구

# %%
# matplotlib 시각화
plt.figure(figsize=(10, 5))
x = data['구'].value_counts()
plt.bar(x.index, x)

plt.xlabel('구')
plt.ylabel('갯수')
plt.title('구역별 공원 갯수')
plt.show()

# %%
# seaborn 공원면적 시각화 box plot
plt.figure(figsize=(10, 5))
sns.boxplot(x='구', y='면적', data=data)

plt.show()

# %%
#📌 4단계: plotly 시각화
# plotly로 공원 면적에 따른 인터랙티브한 산점도를 그리세요. 
# (x축: 면적, y축: 구, 마커: 공원이름)
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Scatter(x=data['면적'], y=data['구'], mode='markers', text=data['이름']))
fig.show()

# %%
'''
📌 5단계: folium 지도 시각화
folium을 사용하여 모든 공원의 위치를 마커로 지도에 표시하세요.
'''

import folium

map_osm = folium.Map(location=[37.566345, 126.977893], zoom_start=11)
for i in range(len(data)):
    content = data['이름'][i] + '<br>' + '면적 : ' + str(data['면적'][i])
    folium.Marker(
        [data['위도'][i], data['경도'][i]], 
        popup=folium.Popup(content, max_width=200)
    ).add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_28e86b8c64549b281a285297ff8e2f17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_28e86b8c64549b281a285297ff8e2f17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_28e86b8c64549b281a285297ff8e2f17 = L.map(
#                 &quot;map_28e86b8c64549b281a285297ff8e2f17&quot;,
#                 {
#                     center: [37.566345, 126.977893],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eff64653394237d7dd76e04f55a94a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3eff64653394237d7dd76e04f55a94a9.addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#             var marker_c8106c9b6cffdff4c7516b2b27963d99 = L.marker(
#                 [37.4991, 126.9208],
#                 {
# }
#             ).addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#         var popup_40128a7d3fb3da77cd59d35b4149ffad = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_510c39699a0e3543b8bcc9b88af57f74 = $(`&lt;div id=&quot;html_510c39699a0e3543b8bcc9b88af57f74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;보라매공원&lt;br&gt;면적 : 425992&lt;/div&gt;`)[0];
#                 popup_40128a7d3fb3da77cd59d35b4149ffad.setContent(html_510c39699a0e3543b8bcc9b88af57f74);
#
#
#
#         marker_c8106c9b6cffdff4c7516b2b27963d99.bindPopup(popup_40128a7d3fb3da77cd59d35b4149ffad)
#         ;
#
#
#
#
#             var marker_990772efb8586c220047f2420fd82227 = L.marker(
#                 [37.5446, 127.0371],
#                 {
# }
#             ).addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#         var popup_1713c9c10a28d1aeb443ebb224e46b51 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_62da9ec24bcc0cbf1474ff64a28b0063 = $(`&lt;div id=&quot;html_62da9ec24bcc0cbf1474ff64a28b0063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울숲&lt;br&gt;면적 : 1165700&lt;/div&gt;`)[0];
#                 popup_1713c9c10a28d1aeb443ebb224e46b51.setContent(html_62da9ec24bcc0cbf1474ff64a28b0063);
#
#
#
#         marker_990772efb8586c220047f2420fd82227.bindPopup(popup_1713c9c10a28d1aeb443ebb224e46b51)
#         ;
#
#
#
#
#             var marker_6e58245101d681faec55f0c0b7b305ed = L.marker(
#                 [37.5509, 126.9905],
#                 {
# }
#             ).addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#         var popup_4a432f9548a2d3a4088644dbb9d3f3e7 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_a79860bff802d047baf63657974ac964 = $(`&lt;div id=&quot;html_a79860bff802d047baf63657974ac964&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;남산공원&lt;br&gt;면적 : 1191416&lt;/div&gt;`)[0];
#                 popup_4a432f9548a2d3a4088644dbb9d3f3e7.setContent(html_a79860bff802d047baf63657974ac964);
#
#
#
#         marker_6e58245101d681faec55f0c0b7b305ed.bindPopup(popup_4a432f9548a2d3a4088644dbb9d3f3e7)
#         ;
#
#
#
#
#             var marker_ea705964e356f54f7227a362cfa01986 = L.marker(
#                 [37.5683, 126.8986],
#                 {
# }
#             ).addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#         var popup_51462d09d51ad7aede0e0aa431e73584 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_5855963da9e072dd739e922c0d6e9f54 = $(`&lt;div id=&quot;html_5855963da9e072dd739e922c0d6e9f54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;월드컵공원&lt;br&gt;면적 : 2690000&lt;/div&gt;`)[0];
#                 popup_51462d09d51ad7aede0e0aa431e73584.setContent(html_5855963da9e072dd739e922c0d6e9f54);
#
#
#
#         marker_ea705964e356f54f7227a362cfa01986.bindPopup(popup_51462d09d51ad7aede0e0aa431e73584)
#         ;
#
#
#
#
#             var marker_f2340f8e770ef6ee5f9060801271b599 = L.marker(
#                 [37.5485, 127.0746],
#                 {
# }
#             ).addTo(map_28e86b8c64549b281a285297ff8e2f17);
#
#
#         var popup_2cde41018fa58645f2b70ac7d4bceb83 = L.popup({
#   &quot;maxWidth&quot;: 200,
# });
#
#
#
#                 var html_81f8eb879df7ba26f9a0bf904582e0e3 = $(`&lt;div id=&quot;html_81f8eb879df7ba26f9a0bf904582e0e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;어린이대공원&lt;br&gt;면적 : 530000&lt;/div&gt;`)[0];
#                 popup_2cde41018fa58645f2b70ac7d4bceb83.setContent(html_81f8eb879df7ba26f9a0bf904582e0e3);
#
#
#
#         marker_f2340f8e770ef6ee5f9060801271b599.bindPopup(popup_2cde41018fa58645f2b70ac7d4bceb83)
#         ;
#
#
#
#
#             var marker_94f1d3a3c37e1dc9867e3b50ffaa2b41 = L.marker(
#                 [37.5233, 126.9802],
#                 {
# }
